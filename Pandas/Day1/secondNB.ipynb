# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\demishra\\Documents\\DS\\weatherdata.csv")

# %%
df
# Out:
#         day  temp  windspeed  event
# 0  6/1/2021    32          6   Rain
# 1  6/2/2021    35          7  Sunny
# 2  6/3/2021    28          2   Snow
# 3  6/4/2021    24          7   Snow
# 4  6/5/2021    32          4   Rain
# 5  6/6/2021    32          2  Sunny

# %%
df = pd.read_excel("C:\\Users\\demishra\\Documents\\DS\\weatherdata.csv.xlsx","Sheet1")
df
# Out:
#          day  temp  windspeed  event
# 0 2021-06-01    32          6   Rain
# 1 2021-06-02    35          7  Sunny
# 2 2021-06-03    28          2   Snow
# 3 2021-06-04    24          7   Snow
# 4 2021-06-05    32          4   Rain
# 5 2021-06-06    32          2  Sunny

# %%
weather_data = {
    'day': ['1/1/2021','1/2/2021','1/3/2021'],
    'temp': [32,35,28],
    'windspeed':[6,7,2],
    'event': ['rain','sunny','snow']
 }
df =pd.DataFrame(weather_data)
df
# Out:
#         day  temp  windspeed  event
# 0  1/1/2021    32          6   rain
# 1  1/2/2021    35          7  sunny
# 2  1/3/2021    28          2   snow

# %% [raw]
# weatherdata = [('1/1/2021',32,6,'rain'),
#                 ('1/2/2021',35,7,'sunny'),
#                 ('1/3/2021',28,2,'snow')]
# df = pd.DataFrame(weatherdata, columns=["Day","temp","windspeed","event"])
# df

# %%
df
# Out:
#         day  temp  windspeed  event
# 0  1/1/2021    32          6   rain
# 1  1/2/2021    35          7  sunny
# 2  1/3/2021    28          2   snow
